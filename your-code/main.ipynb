# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Before-your-start:" data-toc-modified-id="Before-your-start:-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Before your start:</a></span></li><li><span><a href="#Challenge-1---Explore-The-Dataset" data-toc-modified-id="Challenge-1---Explore-The-Dataset-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Challenge 1 - Explore The Dataset</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Explore-the-data-from-an-bird's-eye-view." data-toc-modified-id="Explore-the-data-from-an-bird's-eye-view.-2.0.0.1"><span class="toc-item-num">2.0.0.1&nbsp;&nbsp;</span>Explore the data from an bird's-eye view.</a></span></li><li><span><a href="#Next,-evaluate-if-the-columns-in-this-dataset-are-strongly-correlated." data-toc-modified-id="Next,-evaluate-if-the-columns-in-this-dataset-are-strongly-correlated.-2.0.0.2"><span class="toc-item-num">2.0.0.2&nbsp;&nbsp;</span>Next, evaluate if the columns in this dataset are strongly correlated.</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Challenge-2---Remove-Column-Collinearity." data-toc-modified-id="Challenge-2---Remove-Column-Collinearity.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Challenge 2 - Remove Column Collinearity.</a></span></li><li><span><a href="#Challenge-3---Handle-Missing-Values" data-toc-modified-id="Challenge-3---Handle-Missing-Values-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Challenge 3 - Handle Missing Values</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#In-the-cells-below,-handle-the-missing-values-from-the-dataset.-Remember-to-comment-the-rationale-of-your-decisions." data-toc-modified-id="In-the-cells-below,-handle-the-missing-values-from-the-dataset.-Remember-to-comment-the-rationale-of-your-decisions.-4.0.0.1"><span class="toc-item-num">4.0.0.1&nbsp;&nbsp;</span>In the cells below, handle the missing values from the dataset. Remember to comment the rationale of your decisions.</a></span></li><li><span><a href="#Again,-examine-the-number-of-missing-values-in-each-column." data-toc-modified-id="Again,-examine-the-number-of-missing-values-in-each-column.-4.0.0.2"><span class="toc-item-num">4.0.0.2&nbsp;&nbsp;</span>Again, examine the number of missing values in each column.</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Challenge-4---Handle-WHOIS_*-Categorical-Data" data-toc-modified-id="Challenge-4---Handle-WHOIS_*-Categorical-Data-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Challenge 4 - Handle <code>WHOIS_*</code> Categorical Data</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#In-the-cells-below,-fix-the-country-values-as-intructed-above." data-toc-modified-id="In-the-cells-below,-fix-the-country-values-as-intructed-above.-5.0.0.1"><span class="toc-item-num">5.0.0.1&nbsp;&nbsp;</span>In the cells below, fix the country values as intructed above.</a></span></li><li><span><a href="#If-a-limited-number-of-values-account-for-the-majority-of-data,-we-can-retain-these-top-values-and-re-label-all-other-rare-values." data-toc-modified-id="If-a-limited-number-of-values-account-for-the-majority-of-data,-we-can-retain-these-top-values-and-re-label-all-other-rare-values.-5.0.0.2"><span class="toc-item-num">5.0.0.2&nbsp;&nbsp;</span>If a limited number of values account for the majority of data, we can retain these top values and re-label all other rare values.</a></span></li><li><span><a href="#After-verifying,-now-let's-keep-the-top-10-values-of-the-column-and-re-label-other-columns-with-OTHER." data-toc-modified-id="After-verifying,-now-let's-keep-the-top-10-values-of-the-column-and-re-label-other-columns-with-OTHER.-5.0.0.3"><span class="toc-item-num">5.0.0.3&nbsp;&nbsp;</span>After verifying, now let's keep the top 10 values of the column and re-label other columns with <code>OTHER</code>.</a></span></li><li><span><a href="#In-the-next-cell,-drop-['WHOIS_STATEPRO',-'WHOIS_REGDATE',-'WHOIS_UPDATED_DATE']." data-toc-modified-id="In-the-next-cell,-drop-['WHOIS_STATEPRO',-'WHOIS_REGDATE',-'WHOIS_UPDATED_DATE'].-5.0.0.4"><span class="toc-item-num">5.0.0.4&nbsp;&nbsp;</span>In the next cell, drop <code>['WHOIS_STATEPRO', 'WHOIS_REGDATE', 'WHOIS_UPDATED_DATE']</code>.</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Challenge-5---Handle-Remaining-Categorical-Data-&amp;-Convert-to-Ordinal" data-toc-modified-id="Challenge-5---Handle-Remaining-Categorical-Data-&amp;-Convert-to-Ordinal-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Challenge 5 - Handle Remaining Categorical Data &amp; Convert to Ordinal</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#URL-is-easy.-We'll-simply-drop-it-because-it-has-too-many-unique-values-that-there's-no-way-for-us-to-consolidate." data-toc-modified-id="URL-is-easy.-We'll-simply-drop-it-because-it-has-too-many-unique-values-that-there's-no-way-for-us-to-consolidate.-6.0.0.1"><span class="toc-item-num">6.0.0.1&nbsp;&nbsp;</span><code>URL</code> is easy. We'll simply drop it because it has too many unique values that there's no way for us to consolidate.</a></span></li><li><span><a href="#Print-the-unique-value-counts-of-CHARSET.-You-see-there-are-only-a-few-unique-values.-So-we-can-keep-it-as-it-is." data-toc-modified-id="Print-the-unique-value-counts-of-CHARSET.-You-see-there-are-only-a-few-unique-values.-So-we-can-keep-it-as-it-is.-6.0.0.2"><span class="toc-item-num">6.0.0.2&nbsp;&nbsp;</span>Print the unique value counts of <code>CHARSET</code>. You see there are only a few unique values. So we can keep it as it is.</a></span></li><li><span><a href="#Before-you-think-of-your-own-solution,-don't-read-the-instructions-that-come-next." data-toc-modified-id="Before-you-think-of-your-own-solution,-don't-read-the-instructions-that-come-next.-6.0.0.3"><span class="toc-item-num">6.0.0.3&nbsp;&nbsp;</span>Before you think of your own solution, don't read the instructions that come next.</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Challenge-6---Modeling,-Prediction,-and-Evaluation" data-toc-modified-id="Challenge-6---Modeling,-Prediction,-and-Evaluation-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Challenge 6 - Modeling, Prediction, and Evaluation</a></span><ul class="toc-item"><li><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#In-this-lab,-we-will-try-two-different-models-and-compare-our-results." data-toc-modified-id="In-this-lab,-we-will-try-two-different-models-and-compare-our-results.-7.0.0.1"><span class="toc-item-num">7.0.0.1&nbsp;&nbsp;</span>In this lab, we will try two different models and compare our results.</a></span></li><li><span><a href="#Our-second-algorithm-is-is-DecisionTreeClassifier" data-toc-modified-id="Our-second-algorithm-is-is-DecisionTreeClassifier-7.0.0.2"><span class="toc-item-num">7.0.0.2&nbsp;&nbsp;</span>Our second algorithm is is DecisionTreeClassifier</a></span></li><li><span><a href="#We'll-create-another-DecisionTreeClassifier-model-with-max_depth=5." data-toc-modified-id="We'll-create-another-DecisionTreeClassifier-model-with-max_depth=5.-7.0.0.3"><span class="toc-item-num">7.0.0.3&nbsp;&nbsp;</span>We'll create another DecisionTreeClassifier model with max_depth=5.</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Bonus-Challenge---Feature-Scaling" data-toc-modified-id="Bonus-Challenge---Feature-Scaling-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Bonus Challenge - Feature Scaling</a></span></li></ul></div>

# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# Import your libraries:

# %matplotlib inline

import numpy as np
import pandas as pd

# %% [markdown]
# In this lab, we will explore a dataset that describes websites with different features and labels them either benign or malicious . We will use supervised learning algorithms to figure out what feature patterns malicious websites are likely to have and use our model to predict malicious websites.
#
# Your features will be:
#
# + URL: it is the anonymous identification of the URL analyzed in the study
# + URL_LENGTH: it is the number of characters in the URL
# + NUMBER_SPECIAL_CHARACTERS: it is number of special characters identified in the URL, such as, “/”, “%”, “#”, “&”, “. “, “=”
# + CHARSET: it is a categorical value and its meaning is the character encoding standard (also called character set).
# + SERVER: it is a categorical value and its meaning is the operative system of the server got from the packet response.
# + CONTENT_LENGTH: it represents the content size of the HTTP header.
# + WHOIS_COUNTRY: it is a categorical variable, its values are the countries we got from the server response (specifically, our script used the API of Whois).
# + WHOIS_STATEPRO: it is a categorical variable, its values are the states we got from the server response (specifically, our script used the API of Whois).
# + WHOIS_REGDATE: Whois provides the server registration date, so, this variable has date values with format DD/MM/YYY HH:MM
# + WHOIS_UPDATED_DATE: Through the Whois we got the last update date from the server analyzed
# + TCP_CONVERSATION_EXCHANGE: This variable is the number of TCP packets exchanged between the server and our honeypot client
# + DIST_REMOTE_TCP_PORT: it is the number of the ports detected and different to TCP
# + REMOTE_IPS: this variable has the total number of IPs connected to the honeypot
# + APP_BYTES: this is the number of bytes transfered
# + SOURCE_APP_PACKETS: packets sent from the honeypot to the server
# + REMOTE_APP_PACKETS: packets received from the server
# + APP_PACKETS: this is the total number of IP packets generated during the communication between the honeypot and the server
# + DNS_QUERY_TIMES: this is the number of DNS packets generated during the communication between the honeypot and the server
# + TYPE: this is a categorical variable, its values represent the type of web page analyzed, specifically, 1 is for malicious websites and 0 is for benign websites
#
# # Challenge 1 - Explore The Dataset
#
# Let's start by exploring the dataset. First load the data file:
#
#
# *Source: [kaggle](https://www.kaggle.com/viratkothari/malicious-and-benign-websites-classification)*

# %%
import pandas as pd
import numpy as np
websites = pd.read_csv('../website.csv')

# %% [markdown]
# #### Explore the data from an bird's-eye view.
#
# You should already been very familiar with the procedures now so we won't provide the instructions step by step. Reflect on what you did in the previous labs and explore the dataset.
#
# Things you'll be looking for:
#
# * What the dataset looks like?
# * What are the data types?
# * Which columns contain the features of the websites?
# * Which column contains the feature we will predict? What is the code standing for benign vs malicious websites?
# * Do we need to transform any of the columns from categorical to ordinal values? If so what are these columns?
#
# Feel free to add additional cells for your explorations. Make sure to comment what you find out.

# %%
# What the dataset looks like?
import pandas as pd
import numpy as np

print(f"Shape: {websites.shape[0]:,} rows × {websites.shape[1]:,} columns")
display(websites.head())
websites.info()  # dtypes, non-null counts
display(websites.describe(include="all").T)  # stats for numeric + categorical
# Out:
# Shape: 1,781 rows × 21 columns
#        URL  URL_LENGTH  NUMBER_SPECIAL_CHARACTERS     CHARSET  \
# 0   M0_109          16                          7  iso-8859-1
# 1  B0_2314          16                          6       UTF-8
# 2   B0_911          16                          6    us-ascii
# 3   B0_113          17                          6  ISO-8859-1
# 4   B0_403          17                          6       UTF-8
#
#                   SERVER  CONTENT_LENGTH WHOIS_COUNTRY WHOIS_STATEPRO  \
# 0                  nginx           263.0           NaN            NaN
# 1          Apache/2.4.10         15087.0           NaN            NaN
# 2  Microsoft-HTTPAPI/2.0           324.0           NaN            NaN
# 3                  nginx           162.0            US             AK
# 4                    NaN        124140.0            US             TX
#
#       WHOIS_REGDATE WHOIS_UPDATED_DATE  ...  DIST_REMOTE_TCP_PORT  REMOTE_IPS  \
# ...

# %%
# What are the data types?
websites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1781 entries, 0 to 1780
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   URL                        1781 non-null   object
#  1   URL_LENGTH                 1781 non-null   int64
#  2   NUMBER_SPECIAL_CHARACTERS  1781 non-null   int64
#  3   CHARSET                    1774 non-null   object
#  4   SERVER                     1605 non-null   object
#  5   CONTENT_LENGTH             969 non-null    float64
#  6   WHOIS_COUNTRY              1475 non-null   object
#  7   WHOIS_STATEPRO             1419 non-null   object
#  8   WHOIS_REGDATE              1654 non-null   object
#  9   WHOIS_UPDATED_DATE         1642 non-null   object
#  10  TCP_CONVERSATION_EXCHANGE  1781 non-null   int64
#  11  DIST_REMOTE_TCP_PORT       1781 non-null   int64
#  12  REMOTE_IPS                 1781 non-null   int64
# ...

# %%
# Which columns contain the features of the websites?
websites.nunique().sort_values()

# target = "Type"   # <-- change to your actual label column name
# Out:
# Type                            2
# CHARSET                         8
# DNS_QUERY_TIMES                10
# REMOTE_IPS                     18
# NUMBER_SPECIAL_CHARACTERS      31
# WHOIS_COUNTRY                  48
# DIST_REMOTE_TCP_PORT           66
# TCP_CONVERSATION_EXCHANGE     103
# SOURCE_APP_PACKETS            113
# APP_PACKETS                   113
# REMOTE_APP_PACKETS            116
# URL_LENGTH                    142
# WHOIS_STATEPRO                181
# SERVER                        238
# WHOIS_UPDATED_DATE            593
# CONTENT_LENGTH                637
# REMOTE_APP_BYTES              822
# APP_BYTES                     825
# SOURCE_APP_BYTES              885
# WHOIS_REGDATE                 890
# URL                          1781
# dtype: int64

# %%
# this to search for any binary-like columns:
binary_cols = [c for c in websites.columns if websites[c].nunique() <= 3]
binary_cols
# Out:
# ['Type']

# %%
# Which column contains the feature we will predict? What is the code standing for benign vs malicious websites?
target = "Type"   # <-- change to your actual label column name

# %%
# List feature columns (everything except target)
features = websites.drop(columns=[target]).columns
print("Feature columns:")
features
# Out:
# Feature columns:
# Index(['URL', 'URL_LENGTH', 'NUMBER_SPECIAL_CHARACTERS', 'CHARSET', 'SERVER',
#        'CONTENT_LENGTH', 'WHOIS_COUNTRY', 'WHOIS_STATEPRO', 'WHOIS_REGDATE',
#        'WHOIS_UPDATED_DATE', 'TCP_CONVERSATION_EXCHANGE',
#        'DIST_REMOTE_TCP_PORT', 'REMOTE_IPS', 'APP_BYTES', 'SOURCE_APP_PACKETS',
#        'REMOTE_APP_PACKETS', 'SOURCE_APP_BYTES', 'REMOTE_APP_BYTES',
#        'APP_PACKETS', 'DNS_QUERY_TIMES'],
#       dtype='object')

# %%
# 0 for bening 1 for maliciuos websites --- Validation code:
# check unique values in target column
websites['Type'].unique()
# Out:
# array([1, 0])

# %%
# Count how many benign vs malicious 
websites['Type'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       1
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1776    1
# 1777    1
# 1778    0
# 1779    0
# 1780    0
# Name: Type, Length: 1781, dtype: int64>

# %%
# Display label meaning as a dictionary (optional helper)
label_meaning = {0: "Benign (Safe)", 1: "Malicious"}
label_meaning
# Out:
# {0: 'Benign (Safe)', 1: 'Malicious'}

# %%
# Add a readable label column (optional)
websites['Type_text'] = websites['Type'].map({0: "Benign", 1: "Malicious"})
websites[['Type', 'Type_text']].head()
# Out:
#    Type  Type_text
# 0     1  Malicious
# 1     0     Benign
# 2     0     Benign
# 3     0     Benign
# 4     0     Benign

# %%
# sanity check
print("0 = Benign (Safe website)")
print("1 = Malicious (Harmful website)")
# Out:
# 0 = Benign (Safe website)
# 1 = Malicious (Harmful website)

# %%
# Do we need to transform any of the columns from categorical to ordinal values? If so what are these columns?
# No — none of the categorical columns in this dataset need to be transformed into ordinal values.
# Ordinal encoding is only used when categories have a natural order (like low → medium → high or small → medium → large).

# %%
import pandas as pd
import numpy as np

# Inspect categorical columns
cat_cols = websites.select_dtypes(exclude=np.number).columns.tolist()
print("Categorical columns:", cat_cols)

# Peek at small unique sets (good candidates for encoding)
for c in cat_cols:
    uniq = websites[c].dropna().unique()
    if len(uniq) <= 20:
        print(f"{c}: {sorted(map(str, uniq))}")
# Out:
# Categorical columns: ['URL', 'CHARSET', 'SERVER', 'WHOIS_COUNTRY', 'WHOIS_STATEPRO', 'WHOIS_REGDATE', 'WHOIS_UPDATED_DATE', 'Type_text']
# CHARSET: ['ISO-8859', 'ISO-8859-1', 'UTF-8', 'iso-8859-1', 'us-ascii', 'utf-8', 'windows-1251', 'windows-1252']
# Type_text: ['Benign', 'Malicious']

# %%
# Column - Why not ordinal
# URL - Text/unique strings
# CHARSET - Encodings (no ranking)
# SERVER - Server names/types
# WHOIS_COUNTRY - Country names
# WHOIS_STATEPRO - Region strings
# WHOIS_REGDATE - Date — must be converted to numeric date features, not ordinal
# WHOIS_UPDATED_DATE - Same as above
# Type_text - Binary classifier target, not ordinal

# %%
# What encoding should we use?
# Column - Suggested transformation
# URL: No one-hot. Instead extract features like length, digits count, hostname, etc.
# CHARSET: One-hot encode
# SERVER: One-hot encode or frequency encode
# WHOIS_COUNTRY: One-hot or frequency encode
# WHOIS_STATEPRO: One-hot or frequency encode
# WHOIS_REGDATE, WHOIS_UPDATED_DATE	Convert to datetime → extract numeric features (age, days since update)
# Type_text: Convert Benign→0, Malicious→1

# %% [markdown]
# The dataset contains several categorical variables, but none of them represent ordered categories.
# Therefore, no categorical column needs to be transformed into an ordinal feature.
# Instead, we will convert:
#
# - Categorical text fields (e.g., CHARSET, SERVER, COUNTRY) using one-hot encoding
#
# - WHOIS date fields to numerical date-based features
#
# - The label (Type_text) into binary values (0 = Benign, 1 = Malicious)

# %% [markdown]
# #### Next, evaluate if the columns in this dataset are strongly correlated.
#
# In the Mushroom supervised learning lab we did recently, we mentioned we are concerned if our dataset has strongly correlated columns because if it is the case we need to choose certain ML algorithms instead of others. We need to evaluate this for our dataset now.
#
# Luckily, most of the columns in this dataset are ordinal which makes things a lot easier for us. In the next cells below, evaluate the level of collinearity of the data.
#
# We provide some general directions for you to consult in order to complete this step:
#
# 1. You will create a correlation matrix using the numeric columns in the dataset.
#
# 1. Create a heatmap using `seaborn` to visualize which columns have high collinearity.
#
# 1. Comment on which columns you might need to remove due to high collinearity.

# %% [markdown]
# 1. Encode the categorical columns (label encoding)
#
# 2. Build a correlation matrix only on numeric features
#
# 3. Plot a heatmap
#
# 4. Comment on multicollinearity

# %%
# 1. Encode Categorical Columns & Compute Correlation
#  excluding URL string text column entirely — it's not useful for direct correlation.
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# Columns to encode (URL removed)
cat_cols = ['CHARSET', 'SERVER', 'WHOIS_COUNTRY', 'WHOIS_STATEPRO',
            'WHOIS_REGDATE', 'WHOIS_UPDATED_DATE', 'Type_text']

# Label encode categorical columns
le = LabelEncoder()
df_encoded = websites.copy()

for col in cat_cols:
    df_encoded[col] = le.fit_transform(df_encoded[col].astype(str))

# Select only numeric columns
df_numeric = df_encoded.select_dtypes(include=['int64','float64'])

# Compute correlation matrix
corr_matrix = df_numeric.corr()

corr_matrix
# Out:
#                            URL_LENGTH  NUMBER_SPECIAL_CHARACTERS   CHARSET  \
# URL_LENGTH                   1.000000                   0.917986 -0.042079
# NUMBER_SPECIAL_CHARACTERS    0.917986                   1.000000 -0.059404
# CHARSET                     -0.042079                  -0.059404  1.000000
# SERVER                      -0.145208                  -0.123426  0.067836
# CONTENT_LENGTH               0.129745                   0.214225  0.083429
# WHOIS_COUNTRY               -0.150181                  -0.142791  0.071746
# WHOIS_STATEPRO              -0.122979                  -0.095803 -0.020458
# WHOIS_REGDATE               -0.144496                  -0.121931 -0.034026
# WHOIS_UPDATED_DATE          -0.105561                  -0.079151 -0.111414
# TCP_CONVERSATION_EXCHANGE   -0.038407                  -0.037459 -0.011923
# DIST_REMOTE_TCP_PORT        -0.039839                  -0.042619  0.014244
# ...

# %%
# Heatmap of Feature Correlation
plt.figure(figsize=(12,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap (Encoded Website Security Dataset)")
plt.show()

# %% [markdown]
# Most features show weak to moderate correlation.
# If any features exceed |0.7| correlation, we need to consider removing one of more of them.
# WHOIS date variables (REGDATE vs UPDATEDDATE) may show some correlation — if ≥0.7, drop one.
# We look for |correlation| ≥ 0.70, as these indicate strong collinearity.

# %% [markdown]
# ### This is an example to know the feacture importance using a ML model

# %%
! pip install xgboost

# %%
from xgboost import XGBClassifier
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Features (drop target)
X = websites._get_numeric_data().drop('Type', axis=1)

# Target
y = websites.Type

# Train XGBoost
xgb = XGBClassifier(
    n_estimators=200,
    learning_rate=0.1,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42
)

xgb.fit(X, y)

# Get feature importance scores
importance = xgb.feature_importances_
features = X.columns

fi_df = pd.DataFrame({
    'Feature': features,
    'Importance': importance
}).sort_values('Importance', ascending=False)

print(fi_df)
# Out:
#                       Feature  Importance
# 8          REMOTE_APP_PACKETS    0.260029
# 4        DIST_REMOTE_TCP_PORT    0.203652
# 6                   APP_BYTES    0.088105
# 9            SOURCE_APP_BYTES    0.078456
# 1   NUMBER_SPECIAL_CHARACTERS    0.077322
# 0                  URL_LENGTH    0.055344
# 2              CONTENT_LENGTH    0.050136
# 10           REMOTE_APP_BYTES    0.043293
# 12            DNS_QUERY_TIMES    0.035551
# 5                  REMOTE_IPS    0.031677
# 7          SOURCE_APP_PACKETS    0.030650
# 3   TCP_CONVERSATION_EXCHANGE    0.027319
# 11                APP_PACKETS    0.018466

# %%
plt.figure(figsize=(10,6))
plt.barh(fi_df['Feature'], fi_df['Importance'])
plt.gca().invert_yaxis()  # Most important on top
plt.title("Feature Importance (XGBoost)")
plt.xlabel("Importance Score")
plt.show()

# %% [markdown]
# Most features show weak to moderate correlation.
# If any features exceed |0.7| correlation, we need to consider removing one of more of them.
# WHOIS date variables (REGDATE vs UPDATEDDATE) may show some correlation — if ≥0.7, drop one.
# We look for |correlation| ≥ 0.70, as these indicate strong collinearity.

# %%
# Challenge 2 - Remove Column Collinearity.
# From the heatmap you created, you should have seen at least 3 columns that can be removed due to high collinearity.
# Remove these columns from the dataset.
# Note that you should remove as few columns as you can. You don't have to remove all the columns at once. But instead, try removing one column, then produce the heatmap again to determine if additional columns should be removed. As long as the dataset no longer contains columns that are correlated for over 90%, you can stop. Also, keep in mind when two columns have high collinearity, you only need to remove one of them but not both.
# In the cells below, remove as few columns as you can to eliminate the high collinearity in the dataset. Make sure to comment on your way so that the instructional team can learn about your thinking process which allows them to give feedback. At the end, print the heatmap again.

# %%
# Create correlation matrix + heatmap function

corr_matrix = df_numeric.corr()
corr_matrix


# Heatmap of Feature Correlation
plt.figure(figsize=(12,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap (Encoded Website Security Dataset)")
plt.show()

# %%
# Removing highly correlated columns one by one
#Based on your earlier heatmap, these were the highly correlated columns

# NUMBER_SPECIAL_CHARACTERS ↔ URL_LENGTH (~0.92)

# WHOIS_REGDATE ↔ WHOIS_UPDATED_DATE (~0.70+)

# SOURCE_APP_PACKETS / REMOTE_APP_PACKETS / APP_PACKETS (~0.95+ cluster)

# REMOTE_APP_BYTES vs APP_BYTES

# %%
# 1) Drop and rebuild numeric view
websites.drop(columns=['NUMBER_SPECIAL_CHARACTERS'], inplace=True)

# (optional) normalize column names to avoid hidden spaces/case issues
websites.rename(columns=lambda c: c.strip(), inplace=True)

df_num = websites.select_dtypes(include=['int64','float64']).drop(
    columns=[c for c in ['Type','Type_text'] if c in websites.columns],
    errors='ignore'
)

# 2) Verify it's really gone
print('Has NUMBER_SPECIAL_CHARACTERS in df_num?',
      'NUMBER_SPECIAL_CHARACTERS' in df_num.columns)
print([c for c in df_num.columns if 'SPECIAL' in c.upper()])  # peek for similarly named cols

# 3) Correlation matrix + heatmap (use df_num, not df_numeric)
corr_matrix = df_num.corr()

import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, cmap='coolwarm', vmin=-1, vmax=1, square=False, cbar=True)
plt.title("Correlation Matrix (after dropping NUMBER_SPECIAL_CHARACTERS)")
plt.tight_layout()
plt.show()
# Out:
# Has NUMBER_SPECIAL_CHARACTERS in df_num? False
# []

# %%
# Remove WHOIS_UPDATED_DATE (keep WHOIS_REGDATE)
# 1) Drop and rebuild numeric view
websites.drop(columns=['WHOIS_UPDATED_DATE'], inplace=True)

# (optional) normalize column names to avoid hidden spaces/case issues
websites.rename(columns=lambda c: c.strip(), inplace=True)

df_num = websites.select_dtypes(include=['int64','float64']).drop(
    columns=[c for c in ['Type','Type_text'] if c in websites.columns],
    errors='ignore'
)

# 2) Verify it's really gone
print('Has WHOIS_UPDATED_DATE in df_num?',
      'WHOIS_UPDATED_DATE' in df_num.columns)
print([c for c in df_num.columns if 'SPECIAL' in c.upper()])  # peek for similarly named cols

# 3) Correlation matrix + heatmap (use df_num, not df_numeric)
corr_matrix = df_num.corr()

import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, cmap='coolwarm', vmin=-1, vmax=1, square=False, cbar=True)
plt.title("Correlation Matrix (after dropping WHOIS_UPDATED_DATE)")
plt.tight_layout()
plt.show()
# Out:
# Has WHOIS_UPDATED_DATE in df_num? False
# []

# %%
# Remove APP_PACKETS as it was ~0.99 correlated with two others

# 1) Drop and rebuild numeric view
websites.drop(columns=['APP_PACKETS'], inplace=True)

# (optional) normalize column names to avoid hidden spaces/case issues
websites.rename(columns=lambda c: c.strip(), inplace=True)

df_num = websites.select_dtypes(include=['int64','float64']).drop(
    columns=[c for c in ['Type','Type_text'] if c in websites.columns],
    errors='ignore'
)

# 2) Verify it's really gone
print('Has APP_PACKETS in df_num?',
      'APP_PACKETS' in df_num.columns)
print([c for c in df_num.columns if 'SPECIAL' in c.upper()])  # peek for similarly named cols

# 3) Correlation matrix + heatmap (use df_num, not df_numeric)
corr_matrix = df_num.corr()

import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, cmap='coolwarm', vmin=-1, vmax=1, square=False, cbar=True)
plt.title("Correlation Matrix (after dropping APP_PACKETS)")
plt.tight_layout()
plt.show()
# Out:
# Has APP_PACKETS in df_num? False
# []

# %%
# Remove REMOTE_APP_BYTES as it is still high in correlation

# 1) Drop and rebuild numeric view
websites.drop(columns=['REMOTE_APP_BYTES'], inplace=True)

# (optional) normalize column names to avoid hidden spaces/case issues
websites.rename(columns=lambda c: c.strip(), inplace=True)

df_num = websites.select_dtypes(include=['int64','float64']).drop(
    columns=[c for c in ['Type','Type_text'] if c in websites.columns],
    errors='ignore'
)

# 2) Verify it's really gone
print('Has REMOTE_APP_BYTES in df_num?',
      'REMOTE_APP_BYTES' in df_num.columns)
print([c for c in df_num.columns if 'SPECIAL' in c.upper()])  # peek for similarly named cols

# 3) Correlation matrix + heatmap (use df_num, not df_numeric)
corr_matrix = df_num.corr()

import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, cmap='coolwarm', vmin=-1, vmax=1, square=False, cbar=True)
plt.title("Correlation Matrix (after dropping REMOTE_APP_BYTEs)")
plt.tight_layout()
plt.show()
# Out:
# Has REMOTE_APP_BYTES in df_num? False
# []

# %% [markdown]
# # Challenge 3 - Handle Missing Values
#
# The next step would be handling missing values. **We start by examining the number of missing values in each column, which you will do in the next cell.**

# %%
# Checking number of missing values in each column
websites.isna().sum().sort_values(ascending=False)
# as percentage:
(websites.isna().sum() / len(websites) * 100).sort_values(ascending=False)
# Out:
# CONTENT_LENGTH               45.592364
# WHOIS_STATEPRO               20.325660
# WHOIS_COUNTRY                17.181359
# SERVER                        9.882089
# WHOIS_REGDATE                 7.130825
# CHARSET                       0.393038
# DNS_QUERY_TIMES               0.056148
# URL                           0.000000
# URL_LENGTH                    0.000000
# TCP_CONVERSATION_EXCHANGE     0.000000
# DIST_REMOTE_TCP_PORT          0.000000
# REMOTE_IPS                    0.000000
# SOURCE_APP_PACKETS            0.000000
# APP_BYTES                     0.000000
# REMOTE_APP_PACKETS            0.000000
# SOURCE_APP_BYTES              0.000000
# Type                          0.000000
# Type_text                     0.000000
# dtype: float64

# %%
# Visualize 
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
sns.heatmap(websites.isna(), cbar=False)
plt.title("Missing Values Heatmap")
plt.show()

# %%
# Firts we will drop the columns with more than 50% of missing 
# 1) Drop columns with more than 50% missing data
threshold = 0.50
na_frac = websites.isna().mean()  # fraction of NaNs per column
cols_to_drop = na_frac[na_frac > threshold].index.tolist()
print("Dropping columns (>50% missing):", cols_to_drop)

websites = websites.drop(columns=cols_to_drop, errors='ignore')
# Out:
# Dropping columns (>50% missing): []

# %%
# Now we will drop the rows with missing data
# 2) Drop rows with any remaining missing values
rows_before = len(websites)
websites = websites.dropna(axis=0, how='any')  # drop rows that contain at least one NaN
rows_after = len(websites)

print(f"Rows before: {rows_before} | after: {rows_after} | dropped: {rows_before - rows_after} "
      f"({(rows_before - rows_after)/max(rows_before,1):.1%})")
# Out:
# Rows before: 1781 | after: 636 | dropped: 1145 (64.3%)

# %% [markdown]
# #### Again, examine the number of missing values in each column.
#
#     If all cleaned, proceed. Otherwise, go back and do more cleaning.

# %%
# Examine missing values in each column
# Recheck missing values after cleaning
websites.isna().sum().sort_values(ascending=False)
# Out:
# URL                          0
# URL_LENGTH                   0
# CHARSET                      0
# SERVER                       0
# CONTENT_LENGTH               0
# WHOIS_COUNTRY                0
# WHOIS_STATEPRO               0
# WHOIS_REGDATE                0
# TCP_CONVERSATION_EXCHANGE    0
# DIST_REMOTE_TCP_PORT         0
# REMOTE_IPS                   0
# APP_BYTES                    0
# SOURCE_APP_PACKETS           0
# REMOTE_APP_PACKETS           0
# SOURCE_APP_BYTES             0
# DNS_QUERY_TIMES              0
# Type                         0
# Type_text                    0
# dtype: int64

# %% [markdown]
# # Challenge 4 - Handle `WHOIS_*` Categorical Data

# %% [markdown]
# There are several categorical columns we need to handle. These columns are:
#
# * `URL`
# * `CHARSET`
# * `SERVER`
# * `WHOIS_COUNTRY`
# * `WHOIS_STATEPRO`
# * `WHOIS_REGDATE`
# * `WHOIS_UPDATED_DATE`
#
# How to handle string columns is always case by case. Let's start by working on `WHOIS_COUNTRY`. Your steps are:
#
# 1. List out the unique values of `WHOIS_COUNTRY`.
# 1. Consolidate the country values with consistent country codes. For example, the following values refer to the same country and should use consistent country code:
#     * `CY` and `Cyprus`
#     * `US` and `us`
#     * `SE` and `se`
#     * `GB`, `United Kingdom`, and `[u'GB'; u'UK']`
#
# #### In the cells below, fix the country values as intructed above.

# %%
websites.WHOIS_COUNTRY.value_counts()
# Out:
# WHOIS_COUNTRY
# US                511
# CA                 41
# AU                 11
# PA                 10
# GB                 10
# JP                  6
# [u'GB'; u'UK']      5
# CH                  5
# AT                  4
# IN                  4
# SC                  2
# UA                  2
# CN                  2
# us                  2
# BS                  2
# UY                  2
# UG                  1
# TR                  1
# KY                  1
# UK                  1
# SI                  1
# RU                  1
# IL                  1
# HK                  1
# NL                  1
# IT                  1
# DE                  1
# BE                  1
# NO                  1
# BY                  1
# AE                  1
# IE                  1
# PH                  1
# Name: count, dtype: int64

# %%
# Your code here
good_country = {'None':'None', 
                'US':'US', 
                'SC':'SC', 
                'GB':'UK', 
                'UK':'UK', 
                'RU':'RU', 
                'AU':'AU', 
                'CA':'CA',
                'PA':'PA',
                'se':'SE', 
                'IN':'IN',
                'LU':'LU', 
                'TH':'TH', 
                "[u'GB'; u'UK']":'UK', 
                'FR':'FR',
                'NL':'NL',
                'UG':'UG', 
                'JP':'JP', 
                'CN':'CN', 
                'SE':'SE',
                'SI':'SI', 
                'IL':'IL', 
                'ru':'RU', 
                'KY':'KY', 
                'AT':'AT', 
                'CZ':'CZ', 
                'PH':'PH', 
                'BE':'BE', 
                'NO':'NO', 
                'TR':'TR', 
                'LV':'LV',
                'DE':'DE', 
                'ES':'ES', 
                'BR':'BR', 
                'us':'US', 
                'KR':'KR', 
                'HK':'HK', 
                'UA':'UA', 
                'CH':'CH', 
                'United Kingdom':'UK',
                'BS':'BS', 
                'PK':'PK', 
                'IT':'IT', 
                'Cyprus':'CY', 
                'BY':'BY', 
                'AE':'AE', 
                'IE':'IE', 
                'UY':'UY', 
                'KG':'KG'}

websites.WHOIS_COUNTRY = websites.WHOIS_COUNTRY.apply(lambda x : good_country[x])

# %%
websites.WHOIS_COUNTRY.unique()
# Out:
# array(['US', 'RU', 'AU', 'CA', 'PA', 'UK', 'IN', 'UG', 'JP', 'SI', 'AT',
#        'CN', 'KY', 'TR', 'SC', 'NL', 'UA', 'CH', 'HK', 'IL', 'DE', 'IT',
#        'BS', 'NO', 'BE', 'BY', 'AE', 'IE', 'PH', 'UY'], dtype=object)

# %% [markdown]
# Since we have fixed the country values, can we convert this column to ordinal now?
#
# Not yet. If you reflect on the previous labs how we handle categorical columns, you probably remember we ended up dropping a lot of those columns because there are too many unique values. Too many unique values in a column is not desirable in machine learning because it makes prediction inaccurate. But there are workarounds under certain conditions. One of the fixable conditions is:
#
# #### If a limited number of values account for the majority of data, we can retain these top values and re-label all other rare values.
#
# The `WHOIS_COUNTRY` column happens to be this case. You can verify it by print a bar chart of the `value_counts` in the next cell to verify:

# %%
import matplotlib.pyplot as plt

country_counts = websites['WHOIS_COUNTRY'].value_counts()

plt.figure(figsize=(12,6))
country_counts.plot(kind='bar')
plt.title("WHOIS_COUNTRY Value Counts")
plt.xlabel("Country")
plt.ylabel("Frequency")
plt.show()

# %%
def print_bar_plot(x,y):
    plt.bar(x, y)
    plt.figure(figsize=(15,15))
    return plt.show()

# %%
print_bar_plot(websites.WHOIS_COUNTRY.unique(),websites.WHOIS_COUNTRY.value_counts());

# %% [markdown]
# #### After verifying, now let's keep the top 10 values of the column and re-label other columns with `OTHER`.

# %%
# keep the top 10 countries in WHOIS_COUNTRY and relabel everything else as OTHER.
import numpy as np
import pandas as pd

# 1) Identify the top 10 most frequent non-null countries
top10 = websites['WHOIS_COUNTRY'].dropna().value_counts().head(10).index

# 2) Relabel values: keep top10, everything else -> 'OTHER'
websites['WHOIS_COUNTRY'] = np.where(
    websites['WHOIS_COUNTRY'].isin(top10),
    websites['WHOIS_COUNTRY'],
    'OTHER'
)

# (Optional) If any NaNs remain, send them to 'OTHER' as well
websites['WHOIS_COUNTRY'] = websites['WHOIS_COUNTRY'].fillna('OTHER')

# 3) Quick check
print("Top categories kept:", list(top10))
print(websites['WHOIS_COUNTRY'].value_counts(dropna=False).head(15))
# Out:
# Top categories kept: ['US', 'CA', 'UK', 'AU', 'PA', 'JP', 'CH', 'AT', 'IN', 'CN']
# WHOIS_COUNTRY
# US       513
# CA        41
# OTHER     24
# UK        16
# AU        11
# PA        10
# JP         6
# CH         5
# IN         4
# AT         4
# CN         2
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,6))
websites['WHOIS_COUNTRY'].value_counts().plot(kind='bar')
plt.title("WHOIS_COUNTRY (Top 10 kept, others relabeled as OTHER)")
plt.xlabel("Country")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Now since `WHOIS_COUNTRY` has been re-labelled, we don't need `WHOIS_STATEPRO` any more because the values of the states or provinces may not be relevant any more. We'll drop this column.
#
# In addition, we will also drop `WHOIS_REGDATE` and `WHOIS_UPDATED_DATE`. These are the registration and update dates of the website domains. Not of our concerns.
#
# #### In the next cell, drop `['WHOIS_STATEPRO', 'WHOIS_REGDATE', 'WHOIS_UPDATED_DATE']`.

# %%
to_drop = ['WHOIS_STATEPRO', 'WHOIS_REGDATE', 'WHOIS_UPDATED_DATE']

# Report which columns actually exist before dropping
existing = [c for c in to_drop if c in websites.columns]
missing  = [c for c in to_drop if c not in websites.columns]
print("Will drop:", existing)
if missing:
    print("Not found (skipped):", missing)

# Drop
websites = websites.drop(columns=existing, errors='ignore')

# Quick check
set(to_drop).intersection(websites.columns)
# Out:
# Will drop: []
# Not found (skipped): ['WHOIS_STATEPRO', 'WHOIS_REGDATE', 'WHOIS_UPDATED_DATE']
# set()

# %%
# List remaining column names
websites.columns.tolist()
# Out:
# ['URL',
#  'URL_LENGTH',
#  'CHARSET',
#  'SERVER',
#  'CONTENT_LENGTH',
#  'WHOIS_COUNTRY',
#  'TCP_CONVERSATION_EXCHANGE',
#  'DIST_REMOTE_TCP_PORT',
#  'REMOTE_IPS',
#  'APP_BYTES',
#  'SOURCE_APP_PACKETS',
#  'REMOTE_APP_PACKETS',
#  'SOURCE_APP_BYTES',
#  'DNS_QUERY_TIMES',
#  'Type',
#  'Type_text']

# %% [markdown]
# # Challenge 5 - Handle Remaining Categorical Data & Convert to Ordinal
#
# Now print the `dtypes` of the data again. Besides `WHOIS_COUNTRY` which we already fixed, there should be 3 categorical columns left: `URL`, `CHARSET`, and `SERVER`.

# %%
# Print dtypes
print(websites.dtypes.sort_index())

# Which columns are still object/category?
cat_cols = websites.select_dtypes(include=['object', 'category']).columns.tolist()
print("\nCategorical-like columns:", cat_cols)

# Verify expectation
expected = {'URL', 'CHARSET', 'SERVER', 'WHOIS_COUNTRY'}
unexpected = [c for c in cat_cols if c not in expected]
missing_expected = [c for c in expected if c not in cat_cols]

print("\nUnexpected categorical columns:", unexpected)
print("Expected-but-missing categorical columns:", missing_expected)

# (Optional) ensure WHOIS_COUNTRY is categorical (after your top-10 + OTHER step)
if 'WHOIS_COUNTRY' in websites.columns:
    websites['WHOIS_COUNTRY'] = websites['WHOIS_COUNTRY'].astype('category')
# Out:
# APP_BYTES                      int64
# CHARSET                       object
# CONTENT_LENGTH               float64
# DIST_REMOTE_TCP_PORT           int64
# DNS_QUERY_TIMES              float64
# REMOTE_APP_PACKETS             int64
# REMOTE_IPS                     int64
# SERVER                        object
# SOURCE_APP_BYTES               int64
# SOURCE_APP_PACKETS             int64
# TCP_CONVERSATION_EXCHANGE      int64
# Type                           int64
# Type_text                     object
# URL                           object
# URL_LENGTH                     int64
# WHOIS_COUNTRY                 object
# dtype: object
#
# Categorical-like columns: ['URL', 'CHARSET', 'SERVER', 'WHOIS_COUNTRY', 'Type_text']
#
# Unexpected categorical columns: ['Type_text']
# Expected-but-missing categorical columns: []

# %%
# Create binary target and remove from features
y = websites['Type_text'].map({'Benign': 0, 'Malicious': 1})
print("Target distribution:\n", y.value_counts())

# Optional: keep original label column around for inspection
# If you prefer to remove it from the working feature table:
X = websites.drop(columns=['Type_text'])
# Out:
# Target distribution:
#  Type_text
# 0    590
# 1     46
# Name: count, dtype: int64

# %% [markdown]
# #### `URL` is easy. We'll simply drop it because it has too many unique values that there's no way for us to consolidate.

# %%
# Drop the raw URL column — too many unique values to encode meaningfully
websites.drop(columns=['URL'], inplace=True, errors='ignore')

print("URL column dropped.")
print("Remaining columns:\n", websites.columns.tolist())
# Out:
# URL column dropped.
# Remaining columns:
#  ['URL_LENGTH', 'CHARSET', 'SERVER', 'CONTENT_LENGTH', 'WHOIS_COUNTRY', 'TCP_CONVERSATION_EXCHANGE', 'DIST_REMOTE_TCP_PORT', 'REMOTE_IPS', 'APP_BYTES', 'SOURCE_APP_PACKETS', 'REMOTE_APP_PACKETS', 'SOURCE_APP_BYTES', 'DNS_QUERY_TIMES', 'Type', 'Type_text']

# %% [markdown]
# #### Print the unique value counts of `CHARSET`. You see there are only a few unique values. So we can keep it as it is.

# %%
# How many unique values?
print("nunique:", websites['CHARSET'].nunique(dropna=False))

# Frequency table (including NaN if any)
websites['CHARSET'].value_counts(dropna=False).sort_values(ascending=False)
# Out:
# nunique: 6
# CHARSET
# UTF-8           200
# ISO-8859-1      169
# utf-8           108
# us-ascii         92
# iso-8859-1       66
# windows-1251      1
# Name: count, dtype: int64

# %% [markdown]
# `SERVER` is a little more complicated. Print its unique values and think about how you can consolidate those values.
#
# #### Before you think of your own solution, don't read the instructions that come next.

# %%
# How many unique values?
print("nunique:", websites['SERVER'].nunique(dropna=False))

# Frequency table (including NaN if any)
websites['SERVER'].value_counts(dropna=False).sort_values(ascending=False)
# Out:
# nunique: 120
# SERVER
# Apache                                                           162
# Microsoft-HTTPAPI/2.0                                             76
# nginx                                                             59
# GSE                                                               46
# Microsoft-IIS/7.5                                                 39
#                                                                 ...
# Boston.com Frontend                                                1
# My Arse                                                            1
# Apache/2.4.17 (Unix) OpenSSL/1.0.1e-fips PHP/5.6.19                1
# Microsoft-IIS/7.5; litigation_essentials.lexisnexis.com  9999      1
# Apache/2.2.16 (Debian)                                             1
# Name: count, Length: 120, dtype: int64

# %% [markdown]
# Although there are so many unique values in the `SERVER` column, there are actually only 3 main server types: `Microsoft`, `Apache`, and `nginx`. Just check if each `SERVER` value contains any of those server types and re-label them. For `SERVER` values that don't contain any of those substrings, label with `Other`.
#
# At the end, your `SERVER` column should only contain 4 unique values: `Microsoft`, `Apache`, `nginx`, and `Other`.

# %%
# Count `SERVER` value counts here
websites['SERVER'].value_counts(dropna=False)
# Out:
# SERVER
# Apache                                                           162
# Microsoft-HTTPAPI/2.0                                             76
# nginx                                                             59
# GSE                                                               46
# Microsoft-IIS/7.5                                                 39
#                                                                 ...
# Boston.com Frontend                                                1
# My Arse                                                            1
# Apache/2.4.17 (Unix) OpenSSL/1.0.1e-fips PHP/5.6.19                1
# Microsoft-IIS/7.5; litigation_essentials.lexisnexis.com  9999      1
# Apache/2.2.16 (Debian)                                             1
# Name: count, Length: 120, dtype: int64

# %%
# Basic shape & dtypes
print("Shape:", websites.shape)
print("\nDtypes:\n", websites.dtypes.sort_index())

# Confirm expected categorical columns are present
cat_cols = websites.select_dtypes(include=['object', 'category']).columns.tolist()
print("\nCategorical-like columns:", cat_cols)

# Quick nulls overview
print("\nMissing values per column (top 10):")
print(websites.isna().sum().sort_values(ascending=False).head(10))

# Peek at the first rows BEFORE dummy encoding
websites.head()
# Out:
# Shape: (636, 15)
#
# Dtypes:
#  APP_BYTES                       int64
# CHARSET                        object
# CONTENT_LENGTH                float64
# DIST_REMOTE_TCP_PORT            int64
# DNS_QUERY_TIMES               float64
# REMOTE_APP_PACKETS              int64
# REMOTE_IPS                      int64
# SERVER                         object
# SOURCE_APP_BYTES                int64
# SOURCE_APP_PACKETS              int64
# TCP_CONVERSATION_EXCHANGE       int64
# Type                            int64
# Type_text                      object
# URL_LENGTH                      int64
# WHOIS_COUNTRY                category
# dtype: object
#
# Categorical-like columns: ['CHARSET', 'SERVER', 'WHOIS_COUNTRY', 'Type_text']
#
# Missing values per column (top 10):
# URL_LENGTH                   0
# CHARSET                      0
# SERVER                       0
# CONTENT_LENGTH               0
# WHOIS_COUNTRY                0
# TCP_CONVERSATION_EXCHANGE    0
# ...

# %% [markdown]
# OK, all our categorical data are fixed now. **Let's convert them to ordinal data using Pandas' `get_dummies` function ([documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html)).** Make sure you drop the categorical columns by passing `drop_first=True` to `get_dummies` as we don't need them any more. **Also, assign the data with dummy values to a new variable `website_dummy`.**

# %%
# drop-in cell to one-hot encode your remaining categorical features 
# and store the result in website_dummy (leaving the target Type_text untouched):

import pandas as pd

# Identify categorical feature columns (exclude the target)
cat_cols = websites.select_dtypes(include=['object', 'category']).columns.tolist()
cat_cols = [c for c in cat_cols if c != 'Type_text']  # don't encode the label

# One-hot encode with drop_first=True to avoid dummy trap
website_dummy = pd.get_dummies(
    websites,
    columns=cat_cols,
    drop_first=True,
    dtype='int8'  # compact dtype
)

print("website_dummy shape:", website_dummy.shape)
website_dummy.head()
# Out:
# website_dummy shape: (636, 146)
#     URL_LENGTH  CONTENT_LENGTH  TCP_CONVERSATION_EXCHANGE  \
# 3           17           162.0                         31
# 6           18           345.0                         12
# 7           19           324.0                          0
# 11          20           324.0                          0
# 16          21           686.0                          6
#
#     DIST_REMOTE_TCP_PORT  REMOTE_IPS  APP_BYTES  SOURCE_APP_PACKETS  \
# 3                     22           3       3812                  39
# 6                      0           3       1189                  14
# 7                      0           0          0                   0
# 11                     0           0          0                   0
# 16                     0           2        603                   8
#
#     REMOTE_APP_PACKETS  SOURCE_APP_BYTES  DNS_QUERY_TIMES  ...  \
# 3                   37             18784              8.0  ...
# ...

# %%
# we want a quick numeric target + features check:
if 'Type_text' in website_dummy.columns:
    y = website_dummy['Type_text'].map({'Benign': 0, 'Malicious': 1})
    X = website_dummy.drop(columns=['Type_text'])
    print("\nX shape:", X.shape, "| y positive rate:", (y==1).mean().round(3))
# Out:
# X shape: (636, 145) | y positive rate: 0.072

# %%
# double check cleaned categorical
for col in ['WHOIS_COUNTRY', 'CHARSET', 'SERVER']:
    if col in websites.columns:
        print(f"\n{col} unique values:", websites[col].nunique(dropna=False))
        print(websites[col].value_counts(dropna=False).head(10))
# Out:
# WHOIS_COUNTRY unique values: 11
# WHOIS_COUNTRY
# US       513
# CA        41
# OTHER     24
# UK        16
# AU        11
# PA        10
# JP         6
# CH         5
# AT         4
# IN         4
# Name: count, dtype: int64
#
# CHARSET unique values: 6
# CHARSET
# UTF-8           200
# ISO-8859-1      169
# utf-8           108
# us-ascii         92
# iso-8859-1       66
# windows-1251      1
# Name: count, dtype: int64
#
# SERVER unique values: 120
# SERVER
# Apache                                                                                       162
# Microsoft-HTTPAPI/2.0                                                                         76
# nginx                                                                                         59
# GSE                                                                                           46
# Microsoft-IIS/7.5                                                                             39
# ...

# %% [markdown]
# Now, inspect `website_dummy` to make sure the data and types are intended - there shouldn't be any categorical columns at this point.

# %%
#  quick check to verify website_dummy is fully numeric and looks right:
# 1) Dtypes overview
print("Shape:", website_dummy.shape)
print("\nDtypes:\n", website_dummy.dtypes.value_counts())

# 2) Confirm there are NO object/category columns
obj_cat_cols = website_dummy.select_dtypes(include=['object','category']).columns.tolist()
print("\nObject/Category columns (should be empty):", obj_cat_cols)

# Optional hard check (raises if any object/category remains)
assert len(obj_cat_cols) == 0, f"Found unexpected categorical columns: {obj_cat_cols}"

# 3) Basic NA check
print("\nAny NaNs left?", website_dummy.isna().any().any())

# 4) Preview first rows
website_dummy.head()
# Out:
# Shape: (636, 146)
#
# Dtypes:
#  int8       134
# int64        9
# float64      2
# object       1
# Name: count, dtype: int64
#
# Object/Category columns (should be empty): ['Type_text']
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[892], line 11
#       8 print("\nObject/Category columns (should be empty):", obj_cat_cols)
#      10 # Optional hard check (raises if any object/category remains)
# ---> 11 assert len(obj_cat_cols) == 0, f"Found unexpected categorical columns: {obj_cat_cols}"
#      13 # 3) Basic NA check
#      14 print("\nAny NaNs left?", website_dummy.isna().any().any())
#
# AssertionError: Found unexpected categorical columns: ['Type_text']

# %%
# Find which columns are still non-numeric
obj_cat_cols = website_dummy.select_dtypes(include=['object','category']).columns.tolist()
print("Non-numeric columns:", obj_cat_cols)

# Example: convert label to numeric (if it's still strings)
if 'Type_text' in website_dummy.columns and website_dummy['Type_text'].dtype == 'object':
    website_dummy['Type_text'] = website_dummy['Type_text'].map({'Benign': 0, 'Malicious': 1}).astype('int8')

# Ensure all columns are numeric (will raise if something can't be converted)
website_dummy = website_dummy.apply(pd.to_numeric, errors='raise')

# Re-run the sanity check
print(website_dummy.dtypes.value_counts())
# Out:
# Non-numeric columns: ['Type_text']
# int8       135
# int64        9
# float64      2
# Name: count, dtype: int64

# %%
# Drop the 'Type_text' from the dummy feature table
website_dummy = website_dummy.drop(columns=['Type_text'], errors='ignore')

print("website_dummy shape:", website_dummy.shape)
website_dummy.head()
# Out:
# website_dummy shape: (636, 145)
#     URL_LENGTH  CONTENT_LENGTH  TCP_CONVERSATION_EXCHANGE  \
# 3           17           162.0                         31
# 6           18           345.0                         12
# 7           19           324.0                          0
# 11          20           324.0                          0
# 16          21           686.0                          6
#
#     DIST_REMOTE_TCP_PORT  REMOTE_IPS  APP_BYTES  SOURCE_APP_PACKETS  \
# 3                     22           3       3812                  39
# 6                      0           3       1189                  14
# 7                      0           0          0                   0
# 11                     0           0          0                   0
# 16                     0           2        603                   8
#
#     REMOTE_APP_PACKETS  SOURCE_APP_BYTES  DNS_QUERY_TIMES  ...  \
# 3                   37             18784              8.0  ...
# ...

# %%
#  quick check to verify website_dummy is fully numeric and looks right:
# 1) Dtypes overview
print("Shape:", website_dummy.shape)
print("\nDtypes:\n", website_dummy.dtypes.value_counts())

# 2) Confirm there are NO object/category columns
obj_cat_cols = website_dummy.select_dtypes(include=['object','category']).columns.tolist()
print("\nObject/Category columns (should be empty):", obj_cat_cols)

# Optional hard check (raises if any object/category remains)
assert len(obj_cat_cols) == 0, f"Found unexpected categorical columns: {obj_cat_cols}"

# 3) Basic NA check
print("\nAny NaNs left?", website_dummy.isna().any().any())

# 4) Preview first rows
website_dummy.head()
# Out:
# Shape: (636, 145)
#
# Dtypes:
#  int8       134
# int64        9
# float64      2
# Name: count, dtype: int64
#
# Object/Category columns (should be empty): []
#
# Any NaNs left? False
#     URL_LENGTH  CONTENT_LENGTH  TCP_CONVERSATION_EXCHANGE  \
# 3           17           162.0                         31
# 6           18           345.0                         12
# 7           19           324.0                          0
# 11          20           324.0                          0
# 16          21           686.0                          6
#
#     DIST_REMOTE_TCP_PORT  REMOTE_IPS  APP_BYTES  SOURCE_APP_PACKETS  \
# 3                     22           3       3812                  39
# 6                      0           3       1189                  14
# 7                      0           0          0                   0
# 11                     0           0          0                   0
# 16                     0           2        603                   8
#
# ...

# %% [markdown]
# # Challenge 6 - Modeling, Prediction, and Evaluation
#
# We'll start off this section by splitting the data to train and test. **Name your 4 variables `X_train`, `X_test`, `y_train`, and `y_test`. Select 80% of the data for training and 20% for testing.**

# %%
# website_dummy = your numeric features (target already dropped)
# y = your numeric target (0/1)

from sklearn.model_selection import train_test_split


# 80/20 split with stratification to keep class balance
X_train, X_test, y_train, y_test = train_test_split(
    website_dummy, y,
    test_size=0.20,
    stratify=y,
    random_state=42
)

# sanity checks
print("X_train:", X_train.shape, "| X_test:", X_test.shape)
print("y_train:", y_train.shape, "| y_test:", y_test.shape)
print("Train positive rate:", (y_train==1).mean().round(3),
      "| Test positive rate:", (y_test==1).mean().round(3))
# Out:
# X_train: (508, 145) | X_test: (128, 145)
# y_train: (508,) | y_test: (128,)
# Train positive rate: 0.073 | Test positive rate: 0.07

# %% [markdown]
# #### In this lab, we will try two different models and compare our results.
#
# The first model we will use in this lab is logistic regression. We have previously learned about logistic regression as a classification algorithm. In the cell below, load `LogisticRegression` from scikit-learn and initialize the model.

# %%
## check if classes in y are balanced
# Count of each class
print(y.value_counts())

# Percentage distribution
print((y.value_counts(normalize=True) * 100).round(2))

## imbalanced
# Out:
# Type_text
# 0    590
# 1     46
# Name: count, dtype: int64
# Type_text
# 0    92.77
# 1     7.23
# Name: proportion, dtype: float64

# %%
from sklearn.linear_model import LogisticRegression

# Initialize model (robust defaults)
log_reg = LogisticRegression(
    solver='lbfgs',        # good general-purpose solver
    max_iter=1000,         # ensure convergence
    n_jobs=None,           # (param not used by LogisticRegression; keep default)
    class_weight=None      # set to 'balanced' if classes are imbalanced
)

#because classes are imbalanced
log_reg = LogisticRegression(solver='lbfgs', max_iter=1000, class_weight='balanced')
log_reg
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000)

# %%
# Your code here:

# %% [markdown]
# Next, fit the model to our training data. We have already separated our data into 4 parts. Use those in your model.

# %%
# Your code here:
# Fit the logistic regression model
log_reg.fit(X_train, y_train)

print("Model training complete.")
print("Intercept:", log_reg.intercept_)
print("Num coefficients:", len(log_reg.coef_[0]))
# Out:
# Model training complete.
# Intercept: [-0.37579682]
# Num coefficients: 145
# c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# finally, import `confusion_matrix` and `accuracy_score` from `sklearn.metrics` and fit our testing data. Assign the fitted data to `y_pred` and print the confusion matrix as well as the accuracy score

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# Predict on the test set
y_pred = log_reg.predict(X_test)

# Confusion matrix & accuracy
cm = confusion_matrix(y_test, y_pred)
acc = accuracy_score(y_test, y_pred)

print("Confusion Matrix:\n", cm)
print("\nAccuracy:", round(acc, 4))
# Out:
# Confusion Matrix:
#  [[119   0]
#  [  0   9]]
#
# Accuracy: 1.0

# %%
import pandas as pd

cm_df = pd.DataFrame(cm, index=['Actual 0','Actual 1'], columns=['Pred 0','Pred 1'])
display(cm_df)
# Out:
#           Pred 0  Pred 1
# Actual 0     119       0
# Actual 1       0       9

# %% [markdown]
# What are your thoughts on the performance of the model? Write your conclusions below.

# %% [markdown]
# A perfect score can sometimes indicate:
# The dataset is very easy to separate;
# Potential data leakage;
# Small test sample or imbalance;
# Strong preprocessing & good features;
# Might be overfitted as data for malicious websites not too much samples.

# %% [markdown]
# ### Your conclusions here:
# A perfect score can sometimes indicate:
# The dataset is very easy to separate;
# Potential data leakage;
# Small test sample or imbalance;
# Strong preprocessing & good features;
#
# Might be overfitted as data for malicious websites not too much samples.
#
# Final Conclusion
#
# The logistic regression model achieved perfect accuracy on the test set, suggesting that the features in this dataset provide very strong signals for distinguishing malicious websites from benign ones. However, because perfect scores are rare in real-world scenarios, we should remain cautious — further evaluation with cross-validation and more diverse data would be recommended to confirm the model’s generalization ability or to test with a second model.

# %% [markdown]
# #### Our second algorithm is is DecisionTreeClassifier
#
# Though is it not required, we will fit a model using the training data and then test the performance of the model using the testing data. Start by loading `DecisionTreeClassifier` from scikit-learn and then initializing and fitting the model. We'll start off with a model where max_depth=3

# %%
from sklearn.tree import DecisionTreeClassifier

# Initialize with specified depth
dt = DecisionTreeClassifier(max_depth=3, random_state=42)

# Fit on training data
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %% [markdown]
# To test your model, compute the predicted probabilities, decide 0 or 1 using a threshold of 0.5 and print the confusion matrix as well as the accuracy score (on the test set!)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# Get predicted probabilities for the positive class (class = 1)
y_proba_dt = dt.predict_proba(X_test)[:, 1]

# Convert probabilities to class predictions using threshold = 0.5
y_pred_dt = (y_proba_dt >= 0.5).astype(int)

# Evaluate performance
cm_dt = confusion_matrix(y_test, y_pred_dt)
acc_dt = accuracy_score(y_test, y_pred_dt)

print("Confusion Matrix (Decision Tree):\n", cm_dt)
print("\nAccuracy (Decision Tree):", round(acc_dt, 4))
# Out:
# Confusion Matrix (Decision Tree):
#  [[119   0]
#  [  0   9]]
#
# Accuracy (Decision Tree): 1.0

# %% [markdown]
# #### We'll create another DecisionTreeClassifier model with max_depth=5.
# Initialize and fit the model below and print the confusion matrix and the accuracy score.

# %%
# Your code here:
from sklearn.tree import DecisionTreeClassifier

# Initialize with specified depth
dt = DecisionTreeClassifier(max_depth=5, random_state=42)

# Fit on training data
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=42)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# Get predicted probabilities for the positive class (class = 1)
y_proba_dt = dt.predict_proba(X_test)[:, 1]

# Convert probabilities to class predictions using threshold = 0.5
y_pred_dt = (y_proba_dt >= 0.5).astype(int)

# Evaluate performance
cm_dt = confusion_matrix(y_test, y_pred_dt)
acc_dt = accuracy_score(y_test, y_pred_dt)

print("Confusion Matrix (Decision Tree):\n", cm_dt)
print("\nAccuracy (Decision Tree):", round(acc_dt, 4))
# Out:
# Confusion Matrix (Decision Tree):
#  [[119   0]
#  [  0   9]]
#
# Accuracy (Decision Tree): 1.0

# %% [markdown]
# Did you see an improvement in the confusion matrix when increasing max_depth to 5? Did you see an improvement in the accuracy score? Write your conclusions below.

# %% [markdown]
# ### Your conclusions here:

# %% [markdown]
# Excellent — both Logistic Regression and the Decision Tree achieved:
#
# Perfect confusion matrix
# 100% accuracy
#
# This dataset is highly separable — the features (URL stats, WHOIS data, server info, etc.) provide extremely strong signals that distinguish malicious websites from benign ones. Both a linear model (Logistic Regression) and a simple interpretable nonlinear model (Decision Tree, depth=3) can classify perfectly.
#
# HOWEVER:
# In real cybersecurity detection systems, 100% accuracy is rare due to:
# evolving threats;adversarial behavior (attackers purposely hiding patterns)
# incomplete or noisy data; unseen attack types
#
# So while this result is valid for this dataset, you’d still apply:
# cross-validation; external dataset testing; robustness
#
# Both Logistic Regression and the Decision Tree achieved perfect classification accuracy on the test set. This indicates that the dataset is highly linearly and non-linearly separable, and the engineered WHOIS and web-page features provide very strong predictive signals. In real-world threat detection, performance would likely be lower due to evolving attack patterns, so future work should include cross-validation, testing on new data, and robustness evaluation. Nonetheless, for this dataset, classical models perform exceptionally well.

# %% [markdown]
# <!-- Add your conclusion here -->

# %% [markdown]
# # Bonus Challenge - Feature Scaling
#
# Problem-solving in machine learning is iterative. You can improve your model prediction with various techniques (there is a sweetspot for the time you spend and the improvement you receive though). Now you've completed only one iteration of ML analysis. There are more iterations you can conduct to make improvements. In order to be able to do that, you will need deeper knowledge in statistics and master more data analysis techniques. In this bootcamp, we don't have time to achieve that advanced goal. But you will make constant efforts after the bootcamp to eventually get there.
#
# However, now we do want you to learn one of the advanced techniques which is called *feature scaling*. The idea of feature scaling is to standardize/normalize the range of independent variables or features of the data. This can make the outliers more apparent so that you can remove them. This step needs to happen during Challenge 6 after you split the training and test data because you don't want to split the data again which makes it impossible to compare your results with and without feature scaling. For general concepts about feature scaling, click [here](https://en.wikipedia.org/wiki/Feature_scaling). To read deeper, click [here](https://medium.com/greyatom/why-how-and-when-to-scale-your-features-4b30ab09db5e).
#
# In the next cell, attempt to improve your model prediction accuracy by means of feature scaling. A library you can utilize is `sklearn.preprocessing.RobustScaler` ([documentation](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.RobustScaler.html)). You'll use the `RobustScaler` to fit and transform your `X_train`, then transform `X_test`. You will use logistic regression to fit and predict your transformed data and obtain the accuracy score in the same way. Compare the accuracy score with your normalized data with the previous accuracy data. Is there an improvement?

# %%
from sklearn.preprocessing import RobustScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# Initialize scaler
scaler = RobustScaler()

# Fit scaler only on training data
X_train_scaled = scaler.fit_transform(X_train)

# Transform test data
X_test_scaled = scaler.transform(X_test)

# Fit logistic regression on scaled data
log_reg_scaled = LogisticRegression(max_iter=1000)
log_reg_scaled.fit(X_train_scaled, y_train)

# Predict on scaled test data
y_pred_scaled = log_reg_scaled.predict(X_test_scaled)

# Evaluate
cm_scaled = confusion_matrix(y_test, y_pred_scaled)
acc_scaled = accuracy_score(y_test, y_pred_scaled)

print("Confusion Matrix (Scaled Logistic Regression):")
print(cm_scaled)
print("\nAccuracy (Scaled Logistic Regression):", round(acc_scaled, 4))
# Out:
# Confusion Matrix (Scaled Logistic Regression):
# [[119   0]
#  [  0   9]]
#
# Accuracy (Scaled Logistic Regression): 1.0

# %% [markdown]
# ## Comments:

# %% [markdown]
# After applying RobustScaler to standardize the features, Logistic Regression achieved the same perfect accuracy as before. This shows that scaling did not provide additional benefit in this particular dataset, likely because the features were already highly separable. However, feature scaling is still a best practice for many machine learning algorithms and more complex datasets.
